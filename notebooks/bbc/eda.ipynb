# %%
import pandas as pd

# %%
df = pd.read_csv('../data/datasets/contents.csv', dtype={'Category':'category'})
df
# Out:
#       Unnamed: 0 File_Name                                            Content  \
# 0              0   237.txt  Microsoft takes on desktop search\n\nMicrosoft...
# 1              1   129.txt  Broadband in the UK growing fast\n\nHigh-speed...
# 2              2   024.txt  Game firm holds 'cast' auditions\n\nVideo game...
# 3              3   319.txt  Why Cell will get the hard sell\n\nThe world i...
# 4              4   276.txt  EA to take on film and TV giants\n\nVideo game...
# ...          ...       ...                                                ...
# 2220        2220   488.txt  Williams battles to Aussie title\n\nSerena Wil...
# 2221        2221   145.txt  Downing injury mars Uefa victory\n\nMiddlesbro...
# 2222        2222   154.txt  Reyes tricked into Real admission\n\nJose Anto...
# 2223        2223   455.txt  Slovakia seal Hopman Cup success\n\nSlovakia c...
# 2224        2224   398.txt  Tigers wary of Farrell 'gamble'\n\nLeicester s...
#
#      Category
# 0        tech
# 1        tech
# 2        tech
# 3        tech
# 4        tech
# ...       ...
# 2220    sport
# 2221    sport
# 2222    sport
# 2223    sport
# 2224    sport
#
# [2225 rows x 4 columns]

# %%
df.groupby('Category').count()[['Content']].plot.bar()
df['News length'] = df['Content'].str.len()

# %%
df['News length'] = df['Content'].str.len()
df.boxplot(column='News length', by='Category')
# Out:
# <AxesSubplot:title={'center':'News length'}, xlabel='Category'>

# %%
df[df['News length'] < df['News length'].quantile(0.95)].boxplot(column='News length', by='Category')
# Out:
# <AxesSubplot:title={'center':'News length'}, xlabel='Category'>
